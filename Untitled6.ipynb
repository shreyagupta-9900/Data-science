# %%
import pandas as pd
file_ = pd.read_csv('student_data.csv',sep=',')
print(file_.head(8))
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
# 5            7          40            9              10
# 6           10          40            4              11
# 7            3          86            7               3
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# 3                      4              55       90.17           Placed
# 4                      8              40       78.82           Placed
# 5                      0              60       72.33           Placed
# 6                      9              50       98.12           Placed
# 7                      7              85      100.00           Placed

# %%
import pandas as pd
dct = {
    'name':['tom','rom','jom'],
    'age':[20,21,22],
    'roll':[1,2,3]
}
df = pd.DataFrame(dct)
print(df)

df1 = pd.DataFrame(dct)
display(df1)

df2 = pd.DataFrame(dct,index=['a','b','c'])
display(df2)
# Out:
#   name  age  roll
# 0  tom   20     1
# 1  rom   21     2
# 2  jom   22     3
#   name  age  roll
# 0  tom   20     1
# 1  rom   21     2
# 2  jom   22     3
#   name  age  roll
# a  tom   20     1
# b  rom   21     2
# c  jom   22     3

# %%
import pandas as pd

df= pd.read_csv('student_data.csv')
# df.head(3)
# df.tail(3)
# df.shape()
# df.info()
# df.describe()
# df.index()
# print(df)

# remove row and column
# df.drop(3)

# remove missing value
df.dropna()

# sort value by column
# df.sort_values('assignments_completed')

# sort index
# df.sort_index()

# check for missing value
# df.isnull()
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# 2                        10              45      100.00           Placed
# 3                         4              55       90.17           Placed
# 4                         8              40       78.82           Placed
# ...                     ...             ...         ...              ...
# 9995                      8              88       69.31       Not Placed
# 9996                      4              87      100.00           Placed
# 9997                     10              37       95.94           Placed
# 9998                      8              52       88.61           Placed
# 9999                     16              52       78.96           Placed
#
# [10000 rows x 8 columns]

# %%
import pandas as pd
df= pd.read_csv('student_data.csv')
df.tail(3)
df[['study_hours', 'internet_usage']]
# Out:
#       study_hours  internet_usage
# 0               7               7
# 1               4               3
# 2              11               6
# 3               8               8
# 4               5               6
# ...           ...             ...
# 9995            2               7
# 9996            7               9
# 9997           10               5
# 9998           10               5
# 9999            2              11
#
# [10000 rows x 2 columns]

# %%
import pandas as pd
df= pd.read_csv('student_data.csv')
df.loc[df['assignments_completed']==8].iloc[1]
# Out:
# study_hours                   5
# attendance                   52
# sleep_hours                   8
# internet_usage                6
# assignments_completed         8
# previous_score               40
# exam_score                78.82
# placement_status         Placed
# Name: 4, dtype: object

# %%
import pandas as pd
df= pd.read_csv('student_data.csv')
# df.loc[df['assignments_completed']>3]
# df['age']=20
df=df.rename(columns={'assignments_complete': 'assign_completed'},inplace=True)
df
