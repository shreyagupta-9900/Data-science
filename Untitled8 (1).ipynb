# %%
class mirai_class:
  strength = 100
  teachers = ['a','b','c']
  division = ['alpha','beta','gama']
  subject = ['DSA','Web Dev', 'DS']
obj=mirai_class()
print(obj.strength)
print(obj.teachers)
print(obj.division)
print(obj.subject)
# Out:
# 100
# ['a', 'b', 'c']
# ['alpha', 'beta', 'gama']
# ['DSA', 'Web Dev', 'DS']

# %%
class student:
    def __init__(self,name,age,grade):
        self.name=name
        self.age=age
        self.grade=grade
a = student('shreya',20,'A')
print(a.name)
print(a.age)
print(a.grade)
# Out:
# shreya
# 20
# A

# %%
class student:
    def __init__(self,name,age):
        self.name=name
        self.age=age

    def display(self):
        print("name:",self.name)
        print("age:",self.age)


a=student('John',20)
a.display()
# Out:
# name: John
# age: 20

# %%
class person:
  def __init__(self,h,w,age):
    self.height=h
    self.weight=w
    self.age=age

class Rahul(person):
  def __init__(self,g,name,b,h,w,age):
    super().__init__(h,w,age)

    self.gender=g
    self.name=name
    self.bank_balance=b
obj=Rahul("male","Rahul",100,5,55,18)
print(obj.age)
# Out:
# 18

# %%
def sum_two_numbers(a, b):
    return a + b

x = int(input("Enter first number: "))
y = int(input("Enter second number: "))

print("Sum =", sum_two_numbers(x, y))



def sum_two_numbers(a, b, c):
    return a + b + c

x = int(input("Enter first number: "))
y = int(input("Enter second number: "))
z = int(input("Enter second number: "))

print("Sum =", sum_two_numbers(x, y, z))
# Out:
# Enter first number: 2
# Enter second number: 5
# Sum = 7
# Enter first number: 7
# Enter second number: 7
# Enter second number: 7
# Sum = 21

# %%
class complex:
  def __init__(self,r,i):
    self.r=r
    self.i=i

  def __add__(self,other):
    # return complex(self.r+other.r,self.i+other.i)
    a=self.r+other.r
    b=self.i+other.i
    return complex(a,b)
    return result
  def display(self):
    print(self.r,'+i',self.i)
a=complex(5,6)
b=complex(6,7)
c=a+b

# print(c.r, c.i)
c.display()
# Out:
# 11 +i 13
