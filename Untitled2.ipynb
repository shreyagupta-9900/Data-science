# %%
def fun_name(parameter)
  # body of the function

# %%
def add(a,b):
  c=a+b
  print(c)

# %%
# lambda function
x=lambda a : 2*a
print(x(2))
# Out:
# 4

# %%
st =""
print (len(st))

st = "anand mishra"
st1 = st.upper()
st2 = st.title()
st3 = st.capitalize()
print(st1)
print(st2)
print(st3)
# Out:
# 0
# ANAND MISHRA
# Anand Mishra
# Anand mishra

# %%
first_name = 'shreya'
last_name = 'gupta'

# strip

first_name=first_name.strip('')
last_name=last_name.strip('')
print(first_name+' '+last_name)
# Out:
# shreya gupta

# %%
a=" today"
b=" weather"
c=" is good "

a=a.upper()
b=b.upper()
c=c.upper()

a=a.strip('')
b=b.strip('')
c=c.strip('')
print(a+b+c)
# Out:
#  TODAY  WEATHER IS GOOD

# %%
a=" today"
b=" weather"
c=" is good "


g=c.replace("good","bad")
a=a.strip('')
b=b.strip('')
c=c.strip('')
print(a+b+g)
# Out:
#  today weather is bad

# %%
a = 'today '
b = 'weather '
c = 'is GooD'
d = a+b+c
s = d.capitalize()
print(s)
g = d.replace("GooD" , "Bad")
print(g)

k = d.startswith("F")
print(k)
# Out:
# Today weather is good
# today weather is Bad
# False

# %%
st = {2,3,4,2,3,2}
print(st)
# Out:
# {2, 3, 4}

# %%
dct={
    "name":["shreya","anjali"],
    "agr": 19,
    "city":"delhi"

}
print(dct)
# Out:
# {'name': ['shreya', 'anjali'], 'agr': 19, 'city': 'delhi'}
